# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib widget
mpl.style.use('fast')
from scipy.io import loadmat

# %%
mat_data = loadmat('/Users/kudretesmer/Desktop/STmicroelectronics/datasets/PHM CHALLENGE/Bearing/12ka/260.mat')

# %%
mat_data['X260RPM']
# Out:
# array([[1746]], dtype=uint16)

# %%
plt.close('all')
fig,axs = plt.subplots(3,1,sharex=True,figsize = [11,6])
axs[0].plot(mat_data['X260_BA_time'])
axs[1].plot(mat_data['X260_DE_time'])
axs[2].plot(mat_data['X260_FE_time'])
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
